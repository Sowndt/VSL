# %%
import pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.layers import Input, Dense, concatenate, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import keras_tuner as kt
import tensorflow as tf # Đảm bảo TensorFlow được import
import os
import cv2
import mediapipe as mp
import keypoint_extract as md # Import keypoint_extract
# Out:
# 2025-07-18 11:21:32.987719: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-18 11:21:33.012757: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# --- Cấu hình đường dẫn và hằng số ---
DATA_PATH = 'data_separate.pickle'
LABEL_BINARIZER_PATH = 'label_binarizer.pkl'
TEST_IMAGE_FOLDER = 'VSL_DATA_2' # Thư mục chứa ảnh test riêng biệt

# %%
# Kích thước chuẩn cho từng loại đặc trưng (phải khớp với create_dataset.py)
MAX_LEN_LEFT_HAND = 21 * 3 # 63
MAX_LEN_RIGHT_HAND = 21 * 3 # 63
MAX_LEN_POSE_BODY = 33 * 3 # 99

# --- 1. Tải dữ liệu huấn luyện và validation ---
try:
    with open(DATA_PATH, 'rb') as f:
        data_dict = pickle.load(f)
except FileNotFoundError:
    print(f"Lỗi: Không tìm thấy file {DATA_PATH}. Hãy chạy create_dataset.py trước.")
    exit()

X_left_hand = np.array(data_dict['data_left_hand'], dtype=np.float32)
X_right_hand = np.array(data_dict['data_right_hand'], dtype=np.float32)
X_pose_body = np.array(data_dict['data_pose_body'], dtype=np.float32)
labels = data_dict['labels']

# %% [markdown]
# # 2. Tiền xử lý nhãn (Labels)

# %%
# Chuyển đổi nhãn từ chuỗi sang số nguyên, sau đó one-hot encoding
lb = LabelBinarizer()
y_encoded = lb.fit_transform(labels)
num_classes = len(lb.classes_)
class_names = lb.classes_  # Lưu lại để sử dụng cho đánh giá

# Ghép nối các đặc trưng thành một vector đầu vào duy nhất  
X_combined = np.concatenate((X_left_hand, X_right_hand, X_pose_body), axis=1)

# Chia dữ liệu
X_train, X_val, y_train, y_val = train_test_split(
    X_combined, y_encoded, test_size=0.2, random_state=42, stratify=labels)

print(f"Kích thước tập huấn luyện: {len(X_train)}")
print(f"Kích thước tập Validation: {len(X_val)}")
# Out:
# Kích thước tập huấn luyện: 54400
# Kích thước tập Validation: 13600

# %%
# Xây dựng mô hình ANN đơn giản
def build_model(hp):
    # Đầu vào là vector đặc trưng đã được ghép nối
    input_layer = Input(shape=(X_combined.shape[1],))
    
    # Layer 1
    x = Dense(
        hp.Int('units_1', min_value=128, max_value=512, step=64),
        activation='relu'
    )(input_layer)
    x = Dropout(hp.Float('dropout_1', min_value=0.2, max_value=0.5, step=0.1))(x)
    
    # Layer 2
    x = Dense(
        hp.Int('units_2', min_value=64, max_value=256, step=32),
        activation='relu'
    )(x)
    x = Dropout(hp.Float('dropout_2', min_value=0.2, max_value=0.5, step=0.1))(x)
    
    # Layer 3
    x = Dense(
        hp.Int('units_3', min_value=32, max_value=128, step=32),
        activation='relu'
    )(x)
    
    # Lớp đầu ra
    output = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=input_layer, outputs=output)
    
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    
    model.compile(optimizer=Adam(learning_rate=hp_learning_rate),
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])
    return model

# %%
# Khởi tạo và chạy Tuner
tuner = kt.Hyperband(
    build_model,
    objective='val_accuracy',
    max_epochs=50,
    factor=3,
    directory='hyperband_dir_ann',
    project_name='sign_language_ann_tuning',
    overwrite=True
)

# %%
print("\nBắt đầu tìm kiếm siêu tham số tốt nhất...")
tuner.search(
    X_train,
    y_train,
    epochs=50,
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)]
)
# Out:
# Trial 90 Complete [00h 00m 47s]
# val_accuracy: 0.5913235545158386
#
# Best val_accuracy So Far: 0.9569852948188782
# Total elapsed time: 00h 25m 54s

# %%
# Chuyển đổi nhãn từ chuỗi sang số nguyên, sau đó one-hot encoding
lb = LabelBinarizer()
y_encoded = lb.fit_transform(labels)
num_classes = len(lb.classes_)
class_names = lb.classes_ # Lưu lại để sử dụng cho đánh giá

print(f"Tổng số mẫu dữ liệu: {len(labels)}")
print(f"Tổng số lớp (từ): {num_classes}")
# Out:
# Tổng số mẫu dữ liệu: 68000
# Tổng số lớp (từ): 68

# %%
# --- 6. Lưu LabelBinarizer ---
try:
    with open(LABEL_BINARIZER_PATH, 'wb') as f:
        pickle.dump(lb, f)
    print(f"\nĐã lưu LabelBinarizer vào file {LABEL_BINARIZER_PATH}")
except Exception as e:
    print(f"Lỗi khi lưu LabelBinarizer: {e}")
# Out:
# Đã lưu LabelBinarizer vào file label_binarizer.pkl

# %%
# --- 4. Chuẩn bị dữ liệu ảnh test từ VSL_DATA_2 để đánh giá các mô hình của Tuner ---
print(f"\n--- Chuẩn bị dữ liệu ảnh test từ {TEST_IMAGE_FOLDER} để đánh giá các mô hình của Tuner ---\n")

mp_hands_test = mp.solutions.hands
mp_pose_test = mp.solutions.pose
hands_test = mp_hands_test.Hands(static_image_mode=True, max_num_hands=2, min_detection_confidence=0.5)
pose_test = mp_pose_test.Pose(static_image_mode=True, min_detection_confidence=0.5)

# Hàm extract đặc trưng từ ảnh cho mô hình đa đầu vào (Tương tự Test_ảnh.py)
def extract_features_from_image_multi_input(img_path):
    img = cv2.imread(img_path)
    if img is None:
        return None, None, None

    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    left_hand_landmarks, right_hand_landmarks = md.extract_hand_landmark(img_rgb, hands_test)
    list_pose = md.extract_body_landmark(img_rgb, pose_test)

    flat_left_hand = [coord for lm in left_hand_landmarks for coord in lm]
    flat_right_hand = [coord for lm in right_hand_landmarks for coord in lm]
    flat_pose_body = [coord for lm in list_pose for coord in lm]

    if len(flat_left_hand) < MAX_LEN_LEFT_HAND:
        flat_left_hand.extend([0.0] * (MAX_LEN_LEFT_HAND - len(flat_left_hand)))
    elif len(flat_left_hand) > MAX_LEN_LEFT_HAND:
        flat_left_hand = flat_left_hand[:MAX_LEN_LEFT_HAND]

    if len(flat_right_hand) < MAX_LEN_RIGHT_HAND:
        flat_right_hand.extend([0.0] * (MAX_LEN_RIGHT_HAND - len(flat_right_hand)))
    elif len(flat_right_hand) > MAX_LEN_RIGHT_HAND:
        flat_right_hand = flat_right_hand[:MAX_LEN_RIGHT_HAND]

    if len(flat_pose_body) < MAX_LEN_POSE_BODY:
        flat_pose_body.extend([0.0] * (MAX_LEN_POSE_BODY - len(flat_pose_body)))
    elif len(flat_pose_body) > MAX_LEN_POSE_BODY:
        flat_pose_body = flat_pose_body[:MAX_LEN_POSE_BODY]

    np_left_hand = np.array(flat_left_hand, dtype=np.float32).reshape(1, -1)
    np_right_hand = np.array(flat_right_hand, dtype=np.float32).reshape(1, -1)
    np_pose_body = np.array(flat_pose_body, dtype=np.float32).reshape(1, -1)

    return np_left_hand, np_right_hand, np_pose_body

# Lấy danh sách file ảnh và label thật từ thư mục test
image_files_test = [f for f in os.listdir(TEST_IMAGE_FOLDER) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
image_label_pairs_test = []
for fname in image_files_test:
    true_label = os.path.splitext(fname)[0]
    if true_label not in class_names:
        print(f"Cảnh báo: Nhãn '{true_label}' từ ảnh '{fname}' không có trong các lớp đã huấn luyện. Bỏ qua ảnh này.")
        continue
    image_label_pairs_test.append((os.path.join(TEST_IMAGE_FOLDER, fname), true_label))

print(f"Tổng số ảnh để test riêng biệt: {len(image_label_pairs_test)}")

# Chuẩn bị dữ liệu test thành các mảng numpy để đưa vào mô hình
X_test_left_eval = []
X_test_right_eval = []
X_test_pose_eval = []
y_test_encoded_eval = []

for img_path_test, true_label_test in image_label_pairs_test:
    xl, xr, xp = extract_features_from_image_multi_input(img_path_test)
    if xl is not None:
        X_test_left_eval.append(xl.flatten())
        X_test_right_eval.append(xr.flatten())
        X_test_pose_eval.append(xp.flatten())
        y_test_encoded_eval.append(true_label_test)

if not X_test_left_eval:
    print("Không có ảnh hợp lệ nào trong VSL_DATA_2 để đánh giá. Vui lòng kiểm tra thư mục và tên file.")
    exit()

X_test_left_eval = np.array(X_test_left_eval, dtype=np.float32)
X_test_right_eval = np.array(X_test_right_eval, dtype=np.float32)
X_test_pose_eval = np.array(X_test_pose_eval, dtype=np.float32)
y_test_encoded_eval = lb.transform(y_test_encoded_eval)
# Out:
# --- Chuẩn bị dữ liệu ảnh test từ VSL_DATA_2 để đánh giá các mô hình của Tuner ---
# I0000 00:00:1752817034.181066   36663 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1752817034.290709  102570 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.133.07), renderer: NVIDIA GeForce RTX 3050 6GB Laptop GPU/PCIe/SSE2
# I0000 00:00:1752817034.295706   36663 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# W0000 00:00:1752817034.307287  102564 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1752817034.319034  102562 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1752817034.407236  102590 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.133.07), renderer: NVIDIA GeForce RTX 3050 6GB Laptop GPU/PCIe/SSE2
# Tổng số ảnh để test riêng biệt: 68
# W0000 00:00:1752817034.458044  102589 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1752817034.482980  102578 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# /home/sowndt/.local/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/sowndt/.local/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   y_type = type_of_target(y)
# --- Đánh giá tất cả các mô hình từ Tuner trên tập ảnh VSL_DATA_2 ---
#
# Đánh giá Trial 1/90 (Trial ID: 0051)...
# /home/sowndt/.local/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 18 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
#   Accuracy trên VSL_DATA_2: 41.18%
# Đánh giá Trial 2/90 (Trial ID: 0050)...
#   Accuracy trên VSL_DATA_2: 44.12%
# Đánh giá Trial 3/90 (Trial ID: 0082)...
#   Accuracy trên VSL_DATA_2: 39.71%
# Đánh giá Trial 4/90 (Trial ID: 0073)...
#   Accuracy trên VSL_DATA_2: 38.24%
# Đánh giá Trial 5/90 (Trial ID: 0072)...
#   Accuracy trên VSL_DATA_2: 44.12%
# Đánh giá Trial 6/90 (Trial ID: 0083)...
#   Accuracy trên VSL_DATA_2: 42.65%
# Đánh giá Trial 7/90 (Trial ID: 0077)...
#   Accuracy trên VSL_DATA_2: 42.65%
# Đánh giá Trial 8/90 (Trial ID: 0048)...
#   Accuracy trên VSL_DATA_2: 38.24%
# Đánh giá Trial 9/90 (Trial ID: 0088)...
#   Accuracy trên VSL_DATA_2: 42.65%
# Đánh giá Trial 10/90 (Trial ID: 0046)...
#   Accuracy trên VSL_DATA_2: 45.59%
# Đánh giá Trial 11/90 (Trial ID: 0049)...
#   Accuracy trên VSL_DATA_2: 38.24%
# Đánh giá Trial 12/90 (Trial ID: 0067)...
#   Accuracy trên VSL_DATA_2: 41.18%
# Đánh giá Trial 13/90 (Trial ID: 0068)...
#   Accuracy trên VSL_DATA_2: 39.71%
# Đánh giá Trial 14/90 (Trial ID: 0069)...
#   Accuracy trên VSL_DATA_2: 41.18%
# Đánh giá Trial 15/90 (Trial ID: 0047)...
#   Accuracy trên VSL_DATA_2: 39.71%
# Đánh giá Trial 16/90 (Trial ID: 0070)...
#   Accuracy trên VSL_DATA_2: 42.65%
# Đánh giá Trial 17/90 (Trial ID: 0071)...
#   Accuracy trên VSL_DATA_2: 36.76%
# Đánh giá Trial 18/90 (Trial ID: 0034)...
#   Accuracy trên VSL_DATA_2: 39.71%
# Đánh giá Trial 19/90 (Trial ID: 0039)...
#   Accuracy trên VSL_DATA_2: 38.24%
# Đánh giá Trial 20/90 (Trial ID: 0084)...
#   Accuracy trên VSL_DATA_2: 41.18%
# Đánh giá Trial 21/90 (Trial ID: 0066)...
#   Accuracy trên VSL_DATA_2: 41.18%
# Đánh giá Trial 22/90 (Trial ID: 0035)...
#   Accuracy trên VSL_DATA_2: 38.24%
# Đánh giá Trial 23/90 (Trial ID: 0060)...
#   Accuracy trên VSL_DATA_2: 39.71%
# Đánh giá Trial 24/90 (Trial ID: 0038)...
#   Accuracy trên VSL_DATA_2: 41.18%
# Đánh giá Trial 25/90 (Trial ID: 0037)...
#   Accuracy trên VSL_DATA_2: 36.76%
# Đánh giá Trial 26/90 (Trial ID: 0057)...
#   Accuracy trên VSL_DATA_2: 39.71%
# Đánh giá Trial 27/90 (Trial ID: 0040)...
#   Accuracy trên VSL_DATA_2: 41.18%
# Đánh giá Trial 28/90 (Trial ID: 0036)...
#   Accuracy trên VSL_DATA_2: 41.18%
# Đánh giá Trial 29/90 (Trial ID: 0042)...
#   Accuracy trên VSL_DATA_2: 42.65%
# Đánh giá Trial 30/90 (Trial ID: 0041)...
#   Accuracy trên VSL_DATA_2: 36.76%
# Đánh giá Trial 31/90 (Trial ID: 0062)...
#   Accuracy trên VSL_DATA_2: 41.18%
# Đánh giá Trial 32/90 (Trial ID: 0052)...
#   Accuracy trên VSL_DATA_2: 36.76%
# Đánh giá Trial 33/90 (Trial ID: 0064)...
#   Accuracy trên VSL_DATA_2: 36.76%
# Đánh giá Trial 34/90 (Trial ID: 0065)...
#   Accuracy trên VSL_DATA_2: 35.29%
# Đánh giá Trial 35/90 (Trial ID: 0044)...
#   Accuracy trên VSL_DATA_2: 38.24%
# Đánh giá Trial 36/90 (Trial ID: 0075)...
#   Accuracy trên VSL_DATA_2: 38.24%
# Đánh giá Trial 37/90 (Trial ID: 0043)...
#   Accuracy trên VSL_DATA_2: 36.76%
# Đánh giá Trial 38/90 (Trial ID: 0054)...
#   Accuracy trên VSL_DATA_2: 38.24%
# Đánh giá Trial 39/90 (Trial ID: 0017)...
#   Accuracy trên VSL_DATA_2: 29.41%
# Đánh giá Trial 40/90 (Trial ID: 0045)...
#   Accuracy trên VSL_DATA_2: 38.24%
# Đánh giá Trial 41/90 (Trial ID: 0012)...
#   Accuracy trên VSL_DATA_2: 33.82%
# Đánh giá Trial 42/90 (Trial ID: 0009)...
#   Accuracy trên VSL_DATA_2: 38.24%
# Đánh giá Trial 43/90 (Trial ID: 0008)...
#   Accuracy trên VSL_DATA_2: 27.94%
# Đánh giá Trial 44/90 (Trial ID: 0021)...
#   Accuracy trên VSL_DATA_2: 25.00%
# Đánh giá Trial 45/90 (Trial ID: 0007)...
#   Accuracy trên VSL_DATA_2: 35.29%
# Đánh giá Trial 46/90 (Trial ID: 0006)...
#   Accuracy trên VSL_DATA_2: 25.00%
# Đánh giá Trial 47/90 (Trial ID: 0079)...
#   Accuracy trên VSL_DATA_2: 23.53%
# Đánh giá Trial 48/90 (Trial ID: 0089)...
#   Accuracy trên VSL_DATA_2: 26.47%
# Đánh giá Trial 49/90 (Trial ID: 0025)...
#   Accuracy trên VSL_DATA_2: 23.53%
# Đánh giá Trial 50/90 (Trial ID: 0031)...
#   Accuracy trên VSL_DATA_2: 22.06%
# Đánh giá Trial 51/90 (Trial ID: 0059)...
#   Accuracy trên VSL_DATA_2: 20.59%
# Đánh giá Trial 52/90 (Trial ID: 0061)...
#   Accuracy trên VSL_DATA_2: 19.12%
# Đánh giá Trial 53/90 (Trial ID: 0010)...
#   Accuracy trên VSL_DATA_2: 20.59%
# Đánh giá Trial 54/90 (Trial ID: 0005)...
#   Accuracy trên VSL_DATA_2: 23.53%
# Đánh giá Trial 55/90 (Trial ID: 0020)...
#   Accuracy trên VSL_DATA_2: 19.12%
# Đánh giá Trial 56/90 (Trial ID: 0011)...
#   Accuracy trên VSL_DATA_2: 19.12%
# Đánh giá Trial 57/90 (Trial ID: 0002)...
#   Accuracy trên VSL_DATA_2: 23.53%
# Đánh giá Trial 58/90 (Trial ID: 0013)...
#   Accuracy trên VSL_DATA_2: 27.94%
# Đánh giá Trial 59/90 (Trial ID: 0074)...
#   Accuracy trên VSL_DATA_2: 14.71%
# Đánh giá Trial 60/90 (Trial ID: 0053)...
#   Accuracy trên VSL_DATA_2: 20.59%
# Đánh giá Trial 61/90 (Trial ID: 0085)...
#   Accuracy trên VSL_DATA_2: 10.29%
# Đánh giá Trial 62/90 (Trial ID: 0058)...
#   Accuracy trên VSL_DATA_2: 17.65%
# Đánh giá Trial 63/90 (Trial ID: 0087)...
#   Accuracy trên VSL_DATA_2: 19.12%
# Đánh giá Trial 64/90 (Trial ID: 0063)...
#   Accuracy trên VSL_DATA_2: 11.76%
# Đánh giá Trial 65/90 (Trial ID: 0018)...
#   Accuracy trên VSL_DATA_2: 17.65%
# Đánh giá Trial 66/90 (Trial ID: 0001)...
#   Accuracy trên VSL_DATA_2: 20.59%
# Đánh giá Trial 67/90 (Trial ID: 0030)...
#   Accuracy trên VSL_DATA_2: 7.35%
# Đánh giá Trial 68/90 (Trial ID: 0027)...
#   Accuracy trên VSL_DATA_2: 7.35%
# Đánh giá Trial 69/90 (Trial ID: 0015)...
#   Accuracy trên VSL_DATA_2: 13.24%
# Đánh giá Trial 70/90 (Trial ID: 0023)...
#   Accuracy trên VSL_DATA_2: 8.82%
# Đánh giá Trial 71/90 (Trial ID: 0003)...
#   Accuracy trên VSL_DATA_2: 5.88%
# Đánh giá Trial 72/90 (Trial ID: 0078)...
#   Accuracy trên VSL_DATA_2: 11.76%
# Đánh giá Trial 73/90 (Trial ID: 0055)...
#   Accuracy trên VSL_DATA_2: 7.35%
# Đánh giá Trial 74/90 (Trial ID: 0000)...
#   Accuracy trên VSL_DATA_2: 5.88%
# Đánh giá Trial 75/90 (Trial ID: 0086)...
#   Accuracy trên VSL_DATA_2: 11.76%
# Đánh giá Trial 76/90 (Trial ID: 0029)...
#   Accuracy trên VSL_DATA_2: 8.82%
# Đánh giá Trial 77/90 (Trial ID: 0016)...
#   Accuracy trên VSL_DATA_2: 10.29%
# Đánh giá Trial 78/90 (Trial ID: 0022)...
#   Accuracy trên VSL_DATA_2: 5.88%
# Đánh giá Trial 79/90 (Trial ID: 0033)...
#   Accuracy trên VSL_DATA_2: 5.88%
# Đánh giá Trial 80/90 (Trial ID: 0004)...
#   Accuracy trên VSL_DATA_2: 5.88%
# Đánh giá Trial 81/90 (Trial ID: 0028)...
#   Accuracy trên VSL_DATA_2: 2.94%
# Đánh giá Trial 82/90 (Trial ID: 0076)...
#   Accuracy trên VSL_DATA_2: 5.88%
# Đánh giá Trial 83/90 (Trial ID: 0024)...
#   Accuracy trên VSL_DATA_2: 5.88%
# Đánh giá Trial 84/90 (Trial ID: 0080)...
#   Accuracy trên VSL_DATA_2: 10.29%
# Đánh giá Trial 85/90 (Trial ID: 0014)...
#   Accuracy trên VSL_DATA_2: 2.94%
# Đánh giá Trial 86/90 (Trial ID: 0019)...
#   Accuracy trên VSL_DATA_2: 7.35%
# Đánh giá Trial 87/90 (Trial ID: 0026)...
#   Accuracy trên VSL_DATA_2: 5.88%
# Đánh giá Trial 88/90 (Trial ID: 0056)...
#   Accuracy trên VSL_DATA_2: 5.88%
# Đánh giá Trial 89/90 (Trial ID: 0081)...
#   Accuracy trên VSL_DATA_2: 2.94%
# Đánh giá Trial 90/90 (Trial ID: 0032)...
#   Accuracy trên VSL_DATA_2: 4.41%
#
# ==== Kết quả đánh giá các mô hình trên VSL_DATA_2 (xếp hạng từ cao nhất) ====
#
# Hạng 1: Trial ID 0046
#   Accuracy trên VSL_DATA_2: 45.59%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.2, 'units_2': 256, 'dropout_2': 0.2, 'units_3': 96, 'learning_rate': 0.001, 'tuner/epochs': 17, 'tuner/initial_epoch': 6, 'tuner/bracket': 3, 'tuner/round': 2, 'tuner/trial_id': '0034'}
#
# Hạng 2: Trial ID 0050
#   Accuracy trên VSL_DATA_2: 44.12%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.2, 'units_2': 256, 'dropout_2': 0.2, 'units_3': 64, 'learning_rate': 0.001, 'tuner/epochs': 50, 'tuner/initial_epoch': 17, 'tuner/bracket': 3, 'tuner/round': 3, 'tuner/trial_id': '0048'}
#
# Hạng 3: Trial ID 0072
#   Accuracy trên VSL_DATA_2: 44.12%
#   Siêu tham số: {'units_1': 512, 'dropout_1': 0.30000000000000004, 'units_2': 128, 'dropout_2': 0.30000000000000004, 'units_3': 128, 'learning_rate': 0.001, 'tuner/epochs': 50, 'tuner/initial_epoch': 17, 'tuner/bracket': 2, 'tuner/round': 2, 'tuner/trial_id': '0067'}
#
# Hạng 4: Trial ID 0083
#   Accuracy trên VSL_DATA_2: 42.65%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.2, 'units_2': 128, 'dropout_2': 0.2, 'units_3': 96, 'learning_rate': 0.0001, 'tuner/epochs': 50, 'tuner/initial_epoch': 17, 'tuner/bracket': 1, 'tuner/round': 1, 'tuner/trial_id': '0075'}
#
# Hạng 5: Trial ID 0077
#   Accuracy trên VSL_DATA_2: 42.65%
#   Siêu tham số: {'units_1': 448, 'dropout_1': 0.2, 'units_2': 224, 'dropout_2': 0.4, 'units_3': 96, 'learning_rate': 0.001, 'tuner/epochs': 17, 'tuner/initial_epoch': 0, 'tuner/bracket': 1, 'tuner/round': 0}
#
# Hạng 6: Trial ID 0088
#   Accuracy trên VSL_DATA_2: 42.65%
#   Siêu tham số: {'units_1': 256, 'dropout_1': 0.4, 'units_2': 224, 'dropout_2': 0.30000000000000004, 'units_3': 128, 'learning_rate': 0.0001, 'tuner/epochs': 50, 'tuner/initial_epoch': 0, 'tuner/bracket': 0, 'tuner/round': 0}
#
# Hạng 7: Trial ID 0070
#   Accuracy trên VSL_DATA_2: 42.65%
#   Siêu tham số: {'units_1': 256, 'dropout_1': 0.30000000000000004, 'units_2': 96, 'dropout_2': 0.30000000000000004, 'units_3': 128, 'learning_rate': 0.001, 'tuner/epochs': 17, 'tuner/initial_epoch': 6, 'tuner/bracket': 2, 'tuner/round': 1, 'tuner/trial_id': '0062'}
#
# Hạng 8: Trial ID 0042
#   Accuracy trên VSL_DATA_2: 42.65%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.2, 'units_2': 64, 'dropout_2': 0.2, 'units_3': 96, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 2, 'tuner/bracket': 3, 'tuner/round': 1, 'tuner/trial_id': '0031'}
#
# Hạng 9: Trial ID 0051
#   Accuracy trên VSL_DATA_2: 41.18%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.2, 'units_2': 256, 'dropout_2': 0.2, 'units_3': 96, 'learning_rate': 0.001, 'tuner/epochs': 50, 'tuner/initial_epoch': 17, 'tuner/bracket': 3, 'tuner/round': 3, 'tuner/trial_id': '0046'}
#
# Hạng 10: Trial ID 0067
#   Accuracy trên VSL_DATA_2: 41.18%
#   Siêu tham số: {'units_1': 512, 'dropout_1': 0.30000000000000004, 'units_2': 128, 'dropout_2': 0.30000000000000004, 'units_3': 128, 'learning_rate': 0.001, 'tuner/epochs': 17, 'tuner/initial_epoch': 6, 'tuner/bracket': 2, 'tuner/round': 1, 'tuner/trial_id': '0066'}
#
# Hạng 11: Trial ID 0069
#   Accuracy trên VSL_DATA_2: 41.18%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.2, 'units_2': 128, 'dropout_2': 0.30000000000000004, 'units_3': 128, 'learning_rate': 0.001, 'tuner/epochs': 17, 'tuner/initial_epoch': 6, 'tuner/bracket': 2, 'tuner/round': 1, 'tuner/trial_id': '0057'}
#
# Hạng 12: Trial ID 0084
#   Accuracy trên VSL_DATA_2: 41.18%
#   Siêu tham số: {'units_1': 128, 'dropout_1': 0.2, 'units_2': 160, 'dropout_2': 0.2, 'units_3': 32, 'learning_rate': 0.0001, 'tuner/epochs': 50, 'tuner/initial_epoch': 17, 'tuner/bracket': 1, 'tuner/round': 1, 'tuner/trial_id': '0079'}
#
# Hạng 13: Trial ID 0066
#   Accuracy trên VSL_DATA_2: 41.18%
#   Siêu tham số: {'units_1': 512, 'dropout_1': 0.30000000000000004, 'units_2': 128, 'dropout_2': 0.30000000000000004, 'units_3': 128, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}
#
# Hạng 14: Trial ID 0038
#   Accuracy trên VSL_DATA_2: 41.18%
#   Siêu tham số: {'units_1': 448, 'dropout_1': 0.30000000000000004, 'units_2': 192, 'dropout_2': 0.30000000000000004, 'units_3': 64, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 2, 'tuner/bracket': 3, 'tuner/round': 1, 'tuner/trial_id': '0021'}
#
# Hạng 15: Trial ID 0040
#   Accuracy trên VSL_DATA_2: 41.18%
#   Siêu tham số: {'units_1': 448, 'dropout_1': 0.30000000000000004, 'units_2': 96, 'dropout_2': 0.2, 'units_3': 96, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 2, 'tuner/bracket': 3, 'tuner/round': 1, 'tuner/trial_id': '0006'}
#
# Hạng 16: Trial ID 0036
#   Accuracy trên VSL_DATA_2: 41.18%
#   Siêu tham số: {'units_1': 192, 'dropout_1': 0.30000000000000004, 'units_2': 256, 'dropout_2': 0.30000000000000004, 'units_3': 96, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 2, 'tuner/bracket': 3, 'tuner/round': 1, 'tuner/trial_id': '0009'}
#
# Hạng 17: Trial ID 0062
#   Accuracy trên VSL_DATA_2: 41.18%
#   Siêu tham số: {'units_1': 256, 'dropout_1': 0.30000000000000004, 'units_2': 96, 'dropout_2': 0.30000000000000004, 'units_3': 128, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}
#
# Hạng 18: Trial ID 0082
#   Accuracy trên VSL_DATA_2: 39.71%
#   Siêu tham số: {'units_1': 448, 'dropout_1': 0.2, 'units_2': 224, 'dropout_2': 0.4, 'units_3': 96, 'learning_rate': 0.001, 'tuner/epochs': 50, 'tuner/initial_epoch': 17, 'tuner/bracket': 1, 'tuner/round': 1, 'tuner/trial_id': '0077'}
#
# Hạng 19: Trial ID 0068
#   Accuracy trên VSL_DATA_2: 39.71%
#   Siêu tham số: {'units_1': 448, 'dropout_1': 0.30000000000000004, 'units_2': 128, 'dropout_2': 0.2, 'units_3': 128, 'learning_rate': 0.001, 'tuner/epochs': 17, 'tuner/initial_epoch': 6, 'tuner/bracket': 2, 'tuner/round': 1, 'tuner/trial_id': '0060'}
#
# Hạng 20: Trial ID 0047
#   Accuracy trên VSL_DATA_2: 39.71%
#   Siêu tham số: {'units_1': 512, 'dropout_1': 0.2, 'units_2': 160, 'dropout_2': 0.2, 'units_3': 64, 'learning_rate': 0.001, 'tuner/epochs': 17, 'tuner/initial_epoch': 6, 'tuner/bracket': 3, 'tuner/round': 2, 'tuner/trial_id': '0039'}
#
# Hạng 21: Trial ID 0034
#   Accuracy trên VSL_DATA_2: 39.71%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.2, 'units_2': 256, 'dropout_2': 0.2, 'units_3': 96, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 2, 'tuner/bracket': 3, 'tuner/round': 1, 'tuner/trial_id': '0017'}
#
# Hạng 22: Trial ID 0060
#   Accuracy trên VSL_DATA_2: 39.71%
#   Siêu tham số: {'units_1': 448, 'dropout_1': 0.30000000000000004, 'units_2': 128, 'dropout_2': 0.2, 'units_3': 128, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}
#
# Hạng 23: Trial ID 0057
#   Accuracy trên VSL_DATA_2: 39.71%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.2, 'units_2': 128, 'dropout_2': 0.30000000000000004, 'units_3': 128, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}
#
# Hạng 24: Trial ID 0073
#   Accuracy trên VSL_DATA_2: 38.24%
#   Siêu tham số: {'units_1': 448, 'dropout_1': 0.30000000000000004, 'units_2': 128, 'dropout_2': 0.2, 'units_3': 128, 'learning_rate': 0.001, 'tuner/epochs': 50, 'tuner/initial_epoch': 17, 'tuner/bracket': 2, 'tuner/round': 2, 'tuner/trial_id': '0068'}
#
# Hạng 25: Trial ID 0048
#   Accuracy trên VSL_DATA_2: 38.24%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.2, 'units_2': 256, 'dropout_2': 0.2, 'units_3': 64, 'learning_rate': 0.001, 'tuner/epochs': 17, 'tuner/initial_epoch': 6, 'tuner/bracket': 3, 'tuner/round': 2, 'tuner/trial_id': '0035'}
#
# Hạng 26: Trial ID 0049
#   Accuracy trên VSL_DATA_2: 38.24%
#   Siêu tham số: {'units_1': 448, 'dropout_1': 0.30000000000000004, 'units_2': 192, 'dropout_2': 0.30000000000000004, 'units_3': 64, 'learning_rate': 0.001, 'tuner/epochs': 17, 'tuner/initial_epoch': 6, 'tuner/bracket': 3, 'tuner/round': 2, 'tuner/trial_id': '0038'}
#
# Hạng 27: Trial ID 0039
#   Accuracy trên VSL_DATA_2: 38.24%
#   Siêu tham số: {'units_1': 512, 'dropout_1': 0.2, 'units_2': 160, 'dropout_2': 0.2, 'units_3': 64, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 2, 'tuner/bracket': 3, 'tuner/round': 1, 'tuner/trial_id': '0007'}
#
# Hạng 28: Trial ID 0035
#   Accuracy trên VSL_DATA_2: 38.24%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.2, 'units_2': 256, 'dropout_2': 0.2, 'units_3': 64, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 2, 'tuner/bracket': 3, 'tuner/round': 1, 'tuner/trial_id': '0012'}
#
# Hạng 29: Trial ID 0044
#   Accuracy trên VSL_DATA_2: 38.24%
#   Siêu tham số: {'units_1': 448, 'dropout_1': 0.30000000000000004, 'units_2': 128, 'dropout_2': 0.4, 'units_3': 32, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 2, 'tuner/bracket': 3, 'tuner/round': 1, 'tuner/trial_id': '0005'}
#
# Hạng 30: Trial ID 0075
#   Accuracy trên VSL_DATA_2: 38.24%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.2, 'units_2': 128, 'dropout_2': 0.2, 'units_3': 96, 'learning_rate': 0.0001, 'tuner/epochs': 17, 'tuner/initial_epoch': 0, 'tuner/bracket': 1, 'tuner/round': 0}
#
# Hạng 31: Trial ID 0054
#   Accuracy trên VSL_DATA_2: 38.24%
#   Siêu tham số: {'units_1': 512, 'dropout_1': 0.2, 'units_2': 64, 'dropout_2': 0.4, 'units_3': 96, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}
#
# Hạng 32: Trial ID 0045
#   Accuracy trên VSL_DATA_2: 38.24%
#   Siêu tham số: {'units_1': 128, 'dropout_1': 0.4, 'units_2': 160, 'dropout_2': 0.30000000000000004, 'units_3': 32, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 2, 'tuner/bracket': 3, 'tuner/round': 1, 'tuner/trial_id': '0020'}
#
# Hạng 33: Trial ID 0009
#   Accuracy trên VSL_DATA_2: 38.24%
#   Siêu tham số: {'units_1': 192, 'dropout_1': 0.30000000000000004, 'units_2': 256, 'dropout_2': 0.30000000000000004, 'units_3': 96, 'learning_rate': 0.001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 34: Trial ID 0071
#   Accuracy trên VSL_DATA_2: 36.76%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.30000000000000004, 'units_2': 160, 'dropout_2': 0.30000000000000004, 'units_3': 32, 'learning_rate': 0.001, 'tuner/epochs': 17, 'tuner/initial_epoch': 6, 'tuner/bracket': 2, 'tuner/round': 1, 'tuner/trial_id': '0052'}
#
# Hạng 35: Trial ID 0037
#   Accuracy trên VSL_DATA_2: 36.76%
#   Siêu tham số: {'units_1': 384, 'dropout_1': 0.30000000000000004, 'units_2': 160, 'dropout_2': 0.2, 'units_3': 96, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 2, 'tuner/bracket': 3, 'tuner/round': 1, 'tuner/trial_id': '0008'}
#
# Hạng 36: Trial ID 0041
#   Accuracy trên VSL_DATA_2: 36.76%
#   Siêu tham số: {'units_1': 512, 'dropout_1': 0.2, 'units_2': 128, 'dropout_2': 0.4, 'units_3': 64, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 2, 'tuner/bracket': 3, 'tuner/round': 1, 'tuner/trial_id': '0025'}
#
# Hạng 37: Trial ID 0052
#   Accuracy trên VSL_DATA_2: 36.76%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.30000000000000004, 'units_2': 160, 'dropout_2': 0.30000000000000004, 'units_3': 32, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}
#
# Hạng 38: Trial ID 0064
#   Accuracy trên VSL_DATA_2: 36.76%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.2, 'units_2': 64, 'dropout_2': 0.30000000000000004, 'units_3': 64, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}
#
# Hạng 39: Trial ID 0043
#   Accuracy trên VSL_DATA_2: 36.76%
#   Siêu tham số: {'units_1': 192, 'dropout_1': 0.4, 'units_2': 160, 'dropout_2': 0.30000000000000004, 'units_3': 32, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 2, 'tuner/bracket': 3, 'tuner/round': 1, 'tuner/trial_id': '0010'}
#
# Hạng 40: Trial ID 0065
#   Accuracy trên VSL_DATA_2: 35.29%
#   Siêu tham số: {'units_1': 128, 'dropout_1': 0.30000000000000004, 'units_2': 192, 'dropout_2': 0.4, 'units_3': 96, 'learning_rate': 0.001, 'tuner/epochs': 6, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}
#
# Hạng 41: Trial ID 0007
#   Accuracy trên VSL_DATA_2: 35.29%
#   Siêu tham số: {'units_1': 512, 'dropout_1': 0.2, 'units_2': 160, 'dropout_2': 0.2, 'units_3': 64, 'learning_rate': 0.001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 42: Trial ID 0012
#   Accuracy trên VSL_DATA_2: 33.82%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.2, 'units_2': 256, 'dropout_2': 0.2, 'units_3': 64, 'learning_rate': 0.001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 43: Trial ID 0017
#   Accuracy trên VSL_DATA_2: 29.41%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.2, 'units_2': 256, 'dropout_2': 0.2, 'units_3': 96, 'learning_rate': 0.001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 44: Trial ID 0008
#   Accuracy trên VSL_DATA_2: 27.94%
#   Siêu tham số: {'units_1': 384, 'dropout_1': 0.30000000000000004, 'units_2': 160, 'dropout_2': 0.2, 'units_3': 96, 'learning_rate': 0.001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 45: Trial ID 0013
#   Accuracy trên VSL_DATA_2: 27.94%
#   Siêu tham số: {'units_1': 128, 'dropout_1': 0.4, 'units_2': 160, 'dropout_2': 0.4, 'units_3': 96, 'learning_rate': 0.001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 46: Trial ID 0089
#   Accuracy trên VSL_DATA_2: 26.47%
#   Siêu tham số: {'units_1': 128, 'dropout_1': 0.2, 'units_2': 224, 'dropout_2': 0.30000000000000004, 'units_3': 128, 'learning_rate': 0.01, 'tuner/epochs': 50, 'tuner/initial_epoch': 0, 'tuner/bracket': 0, 'tuner/round': 0}
#
# Hạng 47: Trial ID 0021
#   Accuracy trên VSL_DATA_2: 25.00%
#   Siêu tham số: {'units_1': 448, 'dropout_1': 0.30000000000000004, 'units_2': 192, 'dropout_2': 0.30000000000000004, 'units_3': 64, 'learning_rate': 0.001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 48: Trial ID 0006
#   Accuracy trên VSL_DATA_2: 25.00%
#   Siêu tham số: {'units_1': 448, 'dropout_1': 0.30000000000000004, 'units_2': 96, 'dropout_2': 0.2, 'units_3': 96, 'learning_rate': 0.001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 49: Trial ID 0079
#   Accuracy trên VSL_DATA_2: 23.53%
#   Siêu tham số: {'units_1': 128, 'dropout_1': 0.2, 'units_2': 160, 'dropout_2': 0.2, 'units_3': 32, 'learning_rate': 0.0001, 'tuner/epochs': 17, 'tuner/initial_epoch': 0, 'tuner/bracket': 1, 'tuner/round': 0}
#
# Hạng 50: Trial ID 0025
#   Accuracy trên VSL_DATA_2: 23.53%
#   Siêu tham số: {'units_1': 512, 'dropout_1': 0.2, 'units_2': 128, 'dropout_2': 0.4, 'units_3': 64, 'learning_rate': 0.001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 51: Trial ID 0005
#   Accuracy trên VSL_DATA_2: 23.53%
#   Siêu tham số: {'units_1': 448, 'dropout_1': 0.30000000000000004, 'units_2': 128, 'dropout_2': 0.4, 'units_3': 32, 'learning_rate': 0.001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 52: Trial ID 0002
#   Accuracy trên VSL_DATA_2: 23.53%
#   Siêu tham số: {'units_1': 128, 'dropout_1': 0.4, 'units_2': 128, 'dropout_2': 0.2, 'units_3': 32, 'learning_rate': 0.001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 53: Trial ID 0031
#   Accuracy trên VSL_DATA_2: 22.06%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.2, 'units_2': 64, 'dropout_2': 0.2, 'units_3': 96, 'learning_rate': 0.001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 54: Trial ID 0059
#   Accuracy trên VSL_DATA_2: 20.59%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.30000000000000004, 'units_2': 256, 'dropout_2': 0.2, 'units_3': 64, 'learning_rate': 0.0001, 'tuner/epochs': 6, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}
#
# Hạng 55: Trial ID 0010
#   Accuracy trên VSL_DATA_2: 20.59%
#   Siêu tham số: {'units_1': 192, 'dropout_1': 0.4, 'units_2': 160, 'dropout_2': 0.30000000000000004, 'units_3': 32, 'learning_rate': 0.001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 56: Trial ID 0053
#   Accuracy trên VSL_DATA_2: 20.59%
#   Siêu tham số: {'units_1': 128, 'dropout_1': 0.2, 'units_2': 96, 'dropout_2': 0.4, 'units_3': 32, 'learning_rate': 0.01, 'tuner/epochs': 6, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}
#
# Hạng 57: Trial ID 0001
#   Accuracy trên VSL_DATA_2: 20.59%
#   Siêu tham số: {'units_1': 256, 'dropout_1': 0.2, 'units_2': 256, 'dropout_2': 0.4, 'units_3': 32, 'learning_rate': 0.01, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 58: Trial ID 0061
#   Accuracy trên VSL_DATA_2: 19.12%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.30000000000000004, 'units_2': 256, 'dropout_2': 0.2, 'units_3': 96, 'learning_rate': 0.0001, 'tuner/epochs': 6, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}
#
# Hạng 59: Trial ID 0020
#   Accuracy trên VSL_DATA_2: 19.12%
#   Siêu tham số: {'units_1': 128, 'dropout_1': 0.4, 'units_2': 160, 'dropout_2': 0.30000000000000004, 'units_3': 32, 'learning_rate': 0.001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 60: Trial ID 0011
#   Accuracy trên VSL_DATA_2: 19.12%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.2, 'units_2': 96, 'dropout_2': 0.2, 'units_3': 96, 'learning_rate': 0.01, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 61: Trial ID 0087
#   Accuracy trên VSL_DATA_2: 19.12%
#   Siêu tham số: {'units_1': 448, 'dropout_1': 0.30000000000000004, 'units_2': 256, 'dropout_2': 0.2, 'units_3': 64, 'learning_rate': 0.01, 'tuner/epochs': 50, 'tuner/initial_epoch': 0, 'tuner/bracket': 0, 'tuner/round': 0}
#
# Hạng 62: Trial ID 0058
#   Accuracy trên VSL_DATA_2: 17.65%
#   Siêu tham số: {'units_1': 448, 'dropout_1': 0.30000000000000004, 'units_2': 128, 'dropout_2': 0.2, 'units_3': 128, 'learning_rate': 0.01, 'tuner/epochs': 6, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}
#
# Hạng 63: Trial ID 0018
#   Accuracy trên VSL_DATA_2: 17.65%
#   Siêu tham số: {'units_1': 448, 'dropout_1': 0.2, 'units_2': 160, 'dropout_2': 0.4, 'units_3': 64, 'learning_rate': 0.01, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 64: Trial ID 0074
#   Accuracy trên VSL_DATA_2: 14.71%
#   Siêu tham số: {'units_1': 256, 'dropout_1': 0.2, 'units_2': 128, 'dropout_2': 0.4, 'units_3': 128, 'learning_rate': 0.01, 'tuner/epochs': 17, 'tuner/initial_epoch': 0, 'tuner/bracket': 1, 'tuner/round': 0}
#
# Hạng 65: Trial ID 0015
#   Accuracy trên VSL_DATA_2: 13.24%
#   Siêu tham số: {'units_1': 512, 'dropout_1': 0.30000000000000004, 'units_2': 64, 'dropout_2': 0.30000000000000004, 'units_3': 96, 'learning_rate': 0.01, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 66: Trial ID 0063
#   Accuracy trên VSL_DATA_2: 11.76%
#   Siêu tham số: {'units_1': 192, 'dropout_1': 0.30000000000000004, 'units_2': 128, 'dropout_2': 0.4, 'units_3': 64, 'learning_rate': 0.0001, 'tuner/epochs': 6, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}
#
# Hạng 67: Trial ID 0078
#   Accuracy trên VSL_DATA_2: 11.76%
#   Siêu tham số: {'units_1': 192, 'dropout_1': 0.30000000000000004, 'units_2': 192, 'dropout_2': 0.4, 'units_3': 96, 'learning_rate': 0.01, 'tuner/epochs': 17, 'tuner/initial_epoch': 0, 'tuner/bracket': 1, 'tuner/round': 0}
#
# Hạng 68: Trial ID 0086
#   Accuracy trên VSL_DATA_2: 11.76%
#   Siêu tham số: {'units_1': 256, 'dropout_1': 0.30000000000000004, 'units_2': 96, 'dropout_2': 0.4, 'units_3': 96, 'learning_rate': 0.01, 'tuner/epochs': 50, 'tuner/initial_epoch': 0, 'tuner/bracket': 0, 'tuner/round': 0}
#
# Hạng 69: Trial ID 0085
#   Accuracy trên VSL_DATA_2: 10.29%
#   Siêu tham số: {'units_1': 192, 'dropout_1': 0.30000000000000004, 'units_2': 128, 'dropout_2': 0.30000000000000004, 'units_3': 32, 'learning_rate': 0.01, 'tuner/epochs': 50, 'tuner/initial_epoch': 0, 'tuner/bracket': 0, 'tuner/round': 0}
#
# Hạng 70: Trial ID 0016
#   Accuracy trên VSL_DATA_2: 10.29%
#   Siêu tham số: {'units_1': 448, 'dropout_1': 0.4, 'units_2': 160, 'dropout_2': 0.30000000000000004, 'units_3': 32, 'learning_rate': 0.01, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 71: Trial ID 0080
#   Accuracy trên VSL_DATA_2: 10.29%
#   Siêu tham số: {'units_1': 384, 'dropout_1': 0.4, 'units_2': 192, 'dropout_2': 0.2, 'units_3': 128, 'learning_rate': 0.01, 'tuner/epochs': 17, 'tuner/initial_epoch': 0, 'tuner/bracket': 1, 'tuner/round': 0}
#
# Hạng 72: Trial ID 0023
#   Accuracy trên VSL_DATA_2: 8.82%
#   Siêu tham số: {'units_1': 384, 'dropout_1': 0.30000000000000004, 'units_2': 160, 'dropout_2': 0.30000000000000004, 'units_3': 96, 'learning_rate': 0.01, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 73: Trial ID 0029
#   Accuracy trên VSL_DATA_2: 8.82%
#   Siêu tham số: {'units_1': 128, 'dropout_1': 0.30000000000000004, 'units_2': 160, 'dropout_2': 0.30000000000000004, 'units_3': 32, 'learning_rate': 0.01, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 74: Trial ID 0030
#   Accuracy trên VSL_DATA_2: 7.35%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.30000000000000004, 'units_2': 192, 'dropout_2': 0.2, 'units_3': 128, 'learning_rate': 0.0001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 75: Trial ID 0027
#   Accuracy trên VSL_DATA_2: 7.35%
#   Siêu tham số: {'units_1': 448, 'dropout_1': 0.30000000000000004, 'units_2': 256, 'dropout_2': 0.30000000000000004, 'units_3': 96, 'learning_rate': 0.0001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 76: Trial ID 0055
#   Accuracy trên VSL_DATA_2: 7.35%
#   Siêu tham số: {'units_1': 192, 'dropout_1': 0.4, 'units_2': 64, 'dropout_2': 0.30000000000000004, 'units_3': 32, 'learning_rate': 0.01, 'tuner/epochs': 6, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}
#
# Hạng 77: Trial ID 0019
#   Accuracy trên VSL_DATA_2: 7.35%
#   Siêu tham số: {'units_1': 192, 'dropout_1': 0.4, 'units_2': 192, 'dropout_2': 0.4, 'units_3': 96, 'learning_rate': 0.0001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 78: Trial ID 0003
#   Accuracy trên VSL_DATA_2: 5.88%
#   Siêu tham số: {'units_1': 128, 'dropout_1': 0.2, 'units_2': 96, 'dropout_2': 0.4, 'units_3': 128, 'learning_rate': 0.01, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 79: Trial ID 0000
#   Accuracy trên VSL_DATA_2: 5.88%
#   Siêu tham số: {'units_1': 448, 'dropout_1': 0.4, 'units_2': 160, 'dropout_2': 0.2, 'units_3': 64, 'learning_rate': 0.0001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 80: Trial ID 0022
#   Accuracy trên VSL_DATA_2: 5.88%
#   Siêu tham số: {'units_1': 384, 'dropout_1': 0.30000000000000004, 'units_2': 160, 'dropout_2': 0.2, 'units_3': 64, 'learning_rate': 0.0001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 81: Trial ID 0033
#   Accuracy trên VSL_DATA_2: 5.88%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.30000000000000004, 'units_2': 96, 'dropout_2': 0.4, 'units_3': 128, 'learning_rate': 0.0001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 82: Trial ID 0004
#   Accuracy trên VSL_DATA_2: 5.88%
#   Siêu tham số: {'units_1': 256, 'dropout_1': 0.4, 'units_2': 128, 'dropout_2': 0.2, 'units_3': 128, 'learning_rate': 0.01, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 83: Trial ID 0076
#   Accuracy trên VSL_DATA_2: 5.88%
#   Siêu tham số: {'units_1': 192, 'dropout_1': 0.4, 'units_2': 64, 'dropout_2': 0.4, 'units_3': 128, 'learning_rate': 0.01, 'tuner/epochs': 17, 'tuner/initial_epoch': 0, 'tuner/bracket': 1, 'tuner/round': 0}
#
# Hạng 84: Trial ID 0024
#   Accuracy trên VSL_DATA_2: 5.88%
#   Siêu tham số: {'units_1': 384, 'dropout_1': 0.2, 'units_2': 96, 'dropout_2': 0.4, 'units_3': 64, 'learning_rate': 0.0001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 85: Trial ID 0026
#   Accuracy trên VSL_DATA_2: 5.88%
#   Siêu tham số: {'units_1': 256, 'dropout_1': 0.4, 'units_2': 64, 'dropout_2': 0.4, 'units_3': 32, 'learning_rate': 0.01, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 86: Trial ID 0056
#   Accuracy trên VSL_DATA_2: 5.88%
#   Siêu tham số: {'units_1': 128, 'dropout_1': 0.4, 'units_2': 256, 'dropout_2': 0.2, 'units_3': 32, 'learning_rate': 0.01, 'tuner/epochs': 6, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}
#
# Hạng 87: Trial ID 0032
#   Accuracy trên VSL_DATA_2: 4.41%
#   Siêu tham số: {'units_1': 128, 'dropout_1': 0.4, 'units_2': 96, 'dropout_2': 0.30000000000000004, 'units_3': 32, 'learning_rate': 0.0001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 88: Trial ID 0028
#   Accuracy trên VSL_DATA_2: 2.94%
#   Siêu tham số: {'units_1': 320, 'dropout_1': 0.4, 'units_2': 96, 'dropout_2': 0.2, 'units_3': 96, 'learning_rate': 0.0001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 89: Trial ID 0014
#   Accuracy trên VSL_DATA_2: 2.94%
#   Siêu tham số: {'units_1': 512, 'dropout_1': 0.30000000000000004, 'units_2': 64, 'dropout_2': 0.30000000000000004, 'units_3': 64, 'learning_rate': 0.0001, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
#
# Hạng 90: Trial ID 0081
#   Accuracy trên VSL_DATA_2: 2.94%
#   Siêu tham số: {'units_1': 512, 'dropout_1': 0.4, 'units_2': 192, 'dropout_2': 0.2, 'units_3': 32, 'learning_rate': 0.01, 'tuner/epochs': 17, 'tuner/initial_epoch': 0, 'tuner/bracket': 1, 'tuner/round': 0}
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Đã chọn Trial ID 0046 làm mô hình cuối cùng.
# Đã lưu mô hình cuối cùng vào file final_model_best_on_VSL_DATA2_combined_input.h5
#
# Đã lưu LabelBinarizer vào file label_binarizer.pkl

# %%
# --- 5. Đánh giá tất cả các mô hình trong Tuner trên tập ảnh VSL_DATA_2 ---
print("\n--- Đánh giá tất cả các mô hình từ Tuner trên tập ảnh VSL_DATA_2 ---\n")

# SỬA ĐỔI DÒNG NÀY: Thay vì tuner.oracle.max_trials (có thể là None), sử dụng len(tuner.oracle.trials)
all_trials = tuner.oracle.get_best_trials(num_trials=len(tuner.oracle.trials)) # Lấy tất cả các trials đã chạy
trial_accuracies = []

for i, trial in enumerate(all_trials):
    print(f"Đánh giá Trial {i+1}/{len(all_trials)} (Trial ID: {trial.trial_id})...")
    try:
        # Lấy mô hình từ trial
        model_from_trial = tuner.load_model(trial)
        
        # Đánh giá mô hình trên tập VSL_DATA_2
        loss, accuracy = model_from_trial.evaluate(
            {np.concatenate((X_test_left_eval, X_test_right_eval, X_test_pose_eval), axis=1)},
            y_test_encoded_eval,
            verbose=0
        )
        trial_accuracies.append({'trial_id': trial.trial_id, 'accuracy': accuracy, 'hyperparameters': trial.hyperparameters.values})
        print(f"  Accuracy trên VSL_DATA_2: {accuracy * 100:.2f}%")
    except Exception as e:
        print(f"  Lỗi khi tải hoặc đánh giá mô hình cho Trial {trial.trial_id}: {e}")
        # Bỏ qua trial này hoặc ghi nhận accuracy là 0 nếu có lỗi

# Sắp xếp các mô hình theo accuracy trên VSL_DATA_2 (giảm dần)
trial_accuracies.sort(key=lambda x: x['accuracy'], reverse=True)

print("\n==== Kết quả đánh giá các mô hình trên VSL_DATA_2 (xếp hạng từ cao nhất) ====\n")
if not trial_accuracies:
    print("Không có mô hình nào được đánh giá thành công.")
else:
    for rank, result in enumerate(trial_accuracies):
        print(f"Hạng {rank+1}: Trial ID {result['trial_id']}")
        print(f"  Accuracy trên VSL_DATA_2: {result['accuracy'] * 100:.2f}%")
        print(f"  Siêu tham số: {result['hyperparameters']}\n")

    # Lấy mô hình có accuracy cao nhất trên VSL_DATA_2
    best_model_on_vsl_data2_info = trial_accuracies[0]
    best_model_on_vsl_data2_trial = None
    for trial in all_trials:
        if trial.trial_id == best_model_on_vsl_data2_info['trial_id']:
            best_model_on_vsl_data2_trial = trial
            break

    if best_model_on_vsl_data2_trial:
        final_best_model = tuner.load_model(best_model_on_vsl_data2_trial)
        print(f"\nĐã chọn Trial ID {best_model_on_vsl_data2_info['trial_id']} làm mô hình cuối cùng.")
        final_best_model.save('final_model_best_on_VSL_DATA2.h5')
        print(f"Đã lưu mô hình cuối cùng vào file final_model_best_on_VSL_DATA2.h5")
    else:
        print("\nKhông tìm thấy trial tương ứng cho mô hình tốt nhất để lưu.")
# Out:
# --- Đánh giá tất cả các mô hình từ Tuner trên tập ảnh VSL_DATA_2 ---
#
# Đánh giá Trial 1/90 (Trial ID: 0051)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0051: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 2/90 (Trial ID: 0050)...
# /home/sowndt/.local/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 18 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0050: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 3/90 (Trial ID: 0082)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0082: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 4/90 (Trial ID: 0073)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0073: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 5/90 (Trial ID: 0072)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0072: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 6/90 (Trial ID: 0083)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0083: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 7/90 (Trial ID: 0077)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0077: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 8/90 (Trial ID: 0048)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0048: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 9/90 (Trial ID: 0088)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0088: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 10/90 (Trial ID: 0046)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0046: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 11/90 (Trial ID: 0049)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0049: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 12/90 (Trial ID: 0067)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0067: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 13/90 (Trial ID: 0068)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0068: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 14/90 (Trial ID: 0069)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0069: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 15/90 (Trial ID: 0047)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0047: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 16/90 (Trial ID: 0070)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0070: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 17/90 (Trial ID: 0071)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0071: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 18/90 (Trial ID: 0034)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0034: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 19/90 (Trial ID: 0039)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0039: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 20/90 (Trial ID: 0084)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0084: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 21/90 (Trial ID: 0066)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0066: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 22/90 (Trial ID: 0035)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0035: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 23/90 (Trial ID: 0060)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0060: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 24/90 (Trial ID: 0038)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0038: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 25/90 (Trial ID: 0037)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0037: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 26/90 (Trial ID: 0057)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0057: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 27/90 (Trial ID: 0040)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0040: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 28/90 (Trial ID: 0036)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0036: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 29/90 (Trial ID: 0042)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0042: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 30/90 (Trial ID: 0041)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0041: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 31/90 (Trial ID: 0062)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0062: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 32/90 (Trial ID: 0052)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0052: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 33/90 (Trial ID: 0064)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0064: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 34/90 (Trial ID: 0065)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0065: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 35/90 (Trial ID: 0044)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0044: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 36/90 (Trial ID: 0075)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0075: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 37/90 (Trial ID: 0043)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0043: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 38/90 (Trial ID: 0054)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0054: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 39/90 (Trial ID: 0017)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0017: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 40/90 (Trial ID: 0045)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0045: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 41/90 (Trial ID: 0012)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0012: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 42/90 (Trial ID: 0009)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0009: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 43/90 (Trial ID: 0008)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0008: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 44/90 (Trial ID: 0021)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0021: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 45/90 (Trial ID: 0007)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0007: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 46/90 (Trial ID: 0006)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0006: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 47/90 (Trial ID: 0079)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0079: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 48/90 (Trial ID: 0089)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0089: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 49/90 (Trial ID: 0025)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0025: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 50/90 (Trial ID: 0031)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0031: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 51/90 (Trial ID: 0059)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0059: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 52/90 (Trial ID: 0061)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0061: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 53/90 (Trial ID: 0010)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0010: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 54/90 (Trial ID: 0005)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0005: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 55/90 (Trial ID: 0020)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0020: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 56/90 (Trial ID: 0011)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0011: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 57/90 (Trial ID: 0002)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0002: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 58/90 (Trial ID: 0013)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0013: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 59/90 (Trial ID: 0074)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0074: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 60/90 (Trial ID: 0053)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0053: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 61/90 (Trial ID: 0085)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0085: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 62/90 (Trial ID: 0058)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0058: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 63/90 (Trial ID: 0087)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0087: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 64/90 (Trial ID: 0063)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0063: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 65/90 (Trial ID: 0018)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0018: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 66/90 (Trial ID: 0001)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0001: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 67/90 (Trial ID: 0030)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0030: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 68/90 (Trial ID: 0027)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0027: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 69/90 (Trial ID: 0015)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0015: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 70/90 (Trial ID: 0023)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0023: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 71/90 (Trial ID: 0003)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0003: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 72/90 (Trial ID: 0078)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0078: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 73/90 (Trial ID: 0055)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0055: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 74/90 (Trial ID: 0000)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0000: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 75/90 (Trial ID: 0086)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0086: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 76/90 (Trial ID: 0029)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0029: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 77/90 (Trial ID: 0016)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0016: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 78/90 (Trial ID: 0022)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0022: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 79/90 (Trial ID: 0033)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0033: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 80/90 (Trial ID: 0004)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0004: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 81/90 (Trial ID: 0028)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0028: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 82/90 (Trial ID: 0076)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0076: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 83/90 (Trial ID: 0024)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0024: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 84/90 (Trial ID: 0080)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0080: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 85/90 (Trial ID: 0014)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0014: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 86/90 (Trial ID: 0019)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0019: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 87/90 (Trial ID: 0026)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0026: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 88/90 (Trial ID: 0056)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0056: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 89/90 (Trial ID: 0081)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0081: unhashable type: 'numpy.ndarray'
# Đánh giá Trial 90/90 (Trial ID: 0032)...
#   Lỗi khi tải hoặc đánh giá mô hình cho Trial 0032: unhashable type: 'numpy.ndarray'
#
# ==== Kết quả đánh giá các mô hình trên VSL_DATA_2 (xếp hạng từ cao nhất) ====
#
# Không có mô hình nào được đánh giá thành công.
